# %%
# Importing Libraries
import numpy as np 
import pandas as pd
import requests
import urllib
import json                 
from pprint import pprint  
import csv
from pandas import json_normalize
import math
import datetime

# %%
# List of DMA's Used for For Loop
DMA_List = [200, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 527, 528, 529, 530, 531, 601, 602, 603, 604, 605, 606, 607, 608, 609, 610, 611, 612, 613, 701, 702, 703, 704, 705, 750, 751, 752, 801, 802, 803, 804, 901, 902, 903]
print(len(DMA_List))
print(len(range(0,18)))
# Out:
# 270
# 18

# %%
# Nested For Loop To Take Data From API
Event_Information = []
for DMA in DMA_List:
    for page_num in range(18,36):
        api_url = "https://app.ticketmaster.com/discovery/v2/events?apikey=zDAxzTVTrzQ9NxJ48rOfSMrRmmHXZulL&locale=*&page="+ str(page_num) +'&dmaId=' + str(DMA)
        request_api = requests.get(api_url)
        json_api = request_api.json()
        for package in range(0,20):
            try: EVENTS = json_api['_embedded']['events']
            except: pass
            try: ID = json.dumps(EVENTS[package]['id'])
            except: ID = 'NaN'
            try: Name = json.dumps(EVENTS[package]['name'])
            except: Name = 'NaN'
            try: Event_Tickets = json.dumps(EVENTS[package]['url'])
            except: Event_Tickets = 'NaN'    
            try: Type = json.dumps(EVENTS[package]['type'])
            except: Type = 'NaN'
            try: Date = json.dumps(EVENTS[package]['dates']['start']['localDate'])
            except: Date = 'NaN'
            try: Multiple_Days = json.dumps(EVENTS[package]['dates']['spanMultipleDays'])
            except: Multiple_Days = 'NaN'

            try: Home_Name = json.dumps(EVENTS[package]['_embedded']['attractions'][0]['name'])
            except: Home_Name = 'NaN'
            try: Segment_Home = json.dumps(EVENTS[package]['classifications'][0]['segment']['name'])
            except: Segment_Home = 'NaN'
            try: Genre_Home = json.dumps(EVENTS[package]['classifications'][0]['genre']['name'])
            except: Genre_Home = 'NaN'
            try: SubGenre_Home = json.dumps(EVENTS[package]['classifications'][0]['subGenre']['name'])
            except: SubGenre_Home = 'NaN'
            try: Type_Home = json.dumps(EVENTS[package]['classifications'][0]['type']['name'])
            except: Type_Home = 'NaN'
            try: SubType_Home = json.dumps(EVENTS[package]['classifications'][0]['subType']['name'])
            except: SubType_Home = 'NaN'

            try: Away_Name = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['name'])
            except: Away_Name = 'NaN'
            try: Segment_Away = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['classifications'][0]['segment']['name'])
            except: Segment_Away = 'NaN'
            try: Genre_Away = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['classifications'][0]['genre']['name'])
            except: Genre_Away = 'NaN'
            try: SubGenre_Away = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['classifications'][0]['subGenre']['name'])
            except: SubGenre_Away = 'NaN'
            try: Type_Away = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['classifications'][0]['type']['name'])
            except: Type_Away = 'NaN'
            try: SubType_Away = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['classifications'][0]['subType']['name'])
            except: SubType_Away = 'NaN'

            try: Away_2_Name = json.dumps(EVENTS[package]['_embedded']['attractions'][2]['name'])
            except: Away_2_Name = 'NaN'
            try: Segment_Away_2 = json.dumps(EVENTS[package]['_embedded']['attractions'][2]['classifications'][0]['segment']['name'])
            except: Segment_Away_2 = 'NaN'
            try: Genre_Away_2 = json.dumps(EVENTS[package]['_embedded']['attractions'][2]['classifications'][0]['genre']['name'])
            except: Genre_Away_2 = 'NaN'
            try: SubGenre_Away_2 = json.dumps(EVENTS[package]['_embedded']['attractions'][2]['classifications'][0]['subGenre']['name'])
            except: SubGenre_Away_2 = 'NaN'
            try: Type_Away_2 = json.dumps(EVENTS[package]['_embedded']['attractions'][2]['classifications'][0]['type']['name'])
            except: Type_Away_2 = 'NaN'
            try: SubType_Away_2 = json.dumps(EVENTS[package]['_embedded']['attractions'][2]['classifications'][0]['subType']['name'])
            except: SubType_Away_2 = 'NaN'

            try: Promoter = json.dumps(EVENTS[package]['promoter']['name'])
            except: Promoter = 'NaN'
            try: Price_Ranges_Type = json.dumps(EVENTS[package]['priceRanges'][0]['type'])
            except: Price_Ranges_Type = 'NaN'
            try: Price_Ranges_Currency = json.dumps(EVENTS[package]['priceRanges'][0]['currency'])
            except: Price_Ranges_Currency = 'NaN'
            try: Price_Ranges_Max = json.dumps(EVENTS[package]['priceRanges'][0]['max'])
            except: Price_Ranges_Max = 'NaN'
            try: Price_Ranges_Min = json.dumps(EVENTS[package]['priceRanges'][0]['min'])
            except: Price_Ranges_Min = 'NaN'
            try: Ticket_Limit = json.dumps(EVENTS[package]['accessibility']['ticketLimit'])
            except: Ticket_Limit = 'NaN'
            try: Age_Restrictions = json.dumps(EVENTS[package]['ageRestrictions']['legalAgeEnforced'])
            except: Age_Restrictions = 'NaN'

            try: Venue = json.dumps(EVENTS[package]['_embedded']['venues'][0]['name'])
            except: Venue = 'NaN'
            try: Venue_Alias = json.dumps(EVENTS[package]['_embedded']['venues'][0]['aliases'])
            except: Venue_Alias = 'NaN'
            try: Venue_Type = json.dumps(EVENTS[package]['_embedded']['venues'][0]['type'])
            except: Venue_Type = 'NaN'
            try: Venue_City = json.dumps(EVENTS[package]['_embedded']['venues'][0]['city']['name'])
            except: Venue_City = 'NaN'
            try: Venue_State = json.dumps(EVENTS[package]['_embedded']['venues'][0]['state']['stateCode'])
            except: Venue_State = 'NaN'
            try: Venue_Country = json.dumps(EVENTS[package]['_embedded']['venues'][0]['country']['name'])
            except: Venue_Country = 'NaN'
            try: Venue_Timezone = json.dumps(EVENTS[package]['_embedded']['venues'][0]['timezone'])
            except: Venue_Timezone = 'NaN'

            try: Upcoming_Events_Venue = json.dumps(EVENTS[package]['_embedded']['venues'][0]['upcomingEvents']['_total'])
            except: Upcoming_Events_Venue = 'NaN'
            try: Upcoming_Events_Home = json.dumps(EVENTS[package]['_embedded']['attractions'][0]['upcomingEvents']['_total'])
            except: Upcoming_Events_Home = 'NaN'
            try: Upcoming_Events_Away = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['upcomingEvents']['_total'])
            except: Upcoming_Events_Away = 'NaN'
            try: Upcoming_Events_Away_2 = json.dumps(EVENTS[package]['_embedded']['attractions'][2]['upcomingEvents']['_total'])
            except: Upcoming_Events_Away_2 = 'NaN'

                
            try: Home_Twitter = json.dumps(EVENTS[package]['_embedded']['attractions'][0]['externalLinks']['twitter'][0]['url'])
            except: Home_Twitter = 'NaN'
            try: Home_Facebook = json.dumps(EVENTS[package]['_embedded']['attractions'][0]['externalLinks']['facebook'][0]['url'])
            except: Home_Facebook = 'NaN'
            try: Home_Instagram = json.dumps(EVENTS[package]['_embedded']['attractions'][0]['externalLinks']['instagram'][0]['url'])
            except: Home_Instagram = 'NaN'
            try: Home_Youtube = json.dumps(EVENTS[package]['_embedded']['attractions'][0]['externalLinks']['youtube'][0]['url'])
            except: Home_Youtube = 'NaN'
            try: Home_Homepage = json.dumps(EVENTS[package]['_embedded']['attractions'][0]['externalLinks']['homepage'][0]['url'])
            except: Home_Homepage = 'NaN'
            try: Home_Wiki = json.dumps(EVENTS[package]['_embedded']['attractions'][0]['externalLinks']['wiki'][0]['url'])
            except: Home_Wiki = 'NaN'   
            try: Social_Media_Total_Home = len(json.dumps(EVENTS[package]['_embedded']['attractions'][0]['externalLinks']))
            except: Social_Media_Total_Home = 'NaN'  

            try: Away_Name = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['name'])
            except: Away_Name = 'NaN'
            try: Away_Twitter = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['externalLinks']['twitter'][0]['url'])
            except: Away_Twitter = 'NaN'
            try: Away_Facebook = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['externalLinks']['facebook'][0]['url'])
            except: Away_Facebook = 'NaN'
            try: Away_Instagram = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['externalLinks']['instagram'][0]['url'])
            except: Away_Instagram = 'NaN'
            try: Away_Homepage = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['externalLinks']['homepage'][0]['url'])
            except: Away_Homepage = 'NaN'
            try: Away_Wiki = json.dumps(EVENTS[package]['_embedded']['attractions'][1]['externalLinks']['wiki'][0]['url'])
            except: Away_Wiki = 'NaN'
            try: Social_Media_Total_Away = len(json.dumps(EVENTS[package]['_embedded']['attractions'][1]['externalLinks']))
            except: Social_Media_Total_Away = 'NaN'   
                

            Info = [ID,Name,Event_Tickets,Type,Date,Date,Date,Multiple_Days,Home_Name,Segment_Home,Genre_Home,SubGenre_Home,Type_Home,SubType_Home,Away_Name,Segment_Away,Genre_Away,SubGenre_Away,Type_Away,SubType_Away,Away_2_Name,Segment_Away_2,Genre_Away_2,SubGenre_Away_2,Type_Away_2,SubType_Away_2,Promoter,Price_Ranges_Type,Price_Ranges_Currency,Price_Ranges_Max,Price_Ranges_Min,Ticket_Limit, Age_Restrictions,Venue,Venue_Alias,Venue_Type,Venue_City,Venue_State,Venue_Country,Venue_Timezone,Upcoming_Events_Venue,Upcoming_Events_Home,Upcoming_Events_Away,Upcoming_Events_Away_2,Home_Twitter,Home_Facebook,Home_Instagram,Home_Youtube,Home_Homepage,Home_Wiki,Social_Media_Total_Home,Away_Twitter,Away_Facebook,Away_Instagram,Away_Homepage,Away_Wiki,Social_Media_Total_Away]
            Event_Information.append(Info)

# %%
# Creating List of Columns and Combining with Data to Create Dataframe
Columns = ['ID','Name','Event_Tickets','Type','Year','Month','Day','Multiple_Days','Home_Name','Segment_Home','Genre_Home','SubGenre_Home','Type_Home','SubType_Home','Away_Name','Segment_Away','Genre_Away','SubGenre_Away','Type_Away','SubType_Away','Away_2_Name','Segment_Away_2','Genre_Away_2','SubGenre_Away_2','Type_Away_2','Sub_Type_Away_2','Promoter','Price_Ranges_Type','Price_Ranges_Currency','Price_Ranges_Max','Price_Ranges_Min','Ticket_Limit', 'Age_Restrictions','Venue','Venue_Alias','Venue_Type','Venue_City','Venue_State','Venue_Country','Venue_Timezone','Upcoming_Events_Venue','Upcoming_Events_Home','Upcoming_Events_Away','Upcoming_Events_Away_2','Home_Twitter','Home_Facebook','Home_Instagram','Home_Youtube','Home_Homepage','Home_Wiki','Social_Media_Total_Home','Away_Twitter','Away_Facebook','Away_Instagram','Away_Homepage','Away_Wiki','Social_Media_Total_Away']

df = pd.DataFrame(Event_Information, columns=Columns)

# %%
# Modifying Columns Type and Format
df['Price_Ranges_Max'] = df['Price_Ranges_Max'].astype(float)
df['Price_Ranges_Min'] = df['Price_Ranges_Min'].astype(float)
df['Upcoming_Events_Venue'] = df['Upcoming_Events_Venue'].astype(int, errors ='ignore')
df['Upcoming_Events_Home'] = df['Upcoming_Events_Home'].astype(int, errors ='ignore')
df['Upcoming_Events_Away'] = df['Upcoming_Events_Away'].astype(int, errors ='ignore')
df['Upcoming_Events_Away_2'] = df['Upcoming_Events_Away_2'].astype(int, errors ='ignore')
df['Social_Media_Total_Home'] = df['Social_Media_Total_Home'].astype(int, errors ='ignore')
df['Social_Media_Total_Away'] = df['Social_Media_Total_Away'].astype(int, errors ='ignore')
df['Multiple_Days'] = df['Multiple_Days'].astype(bool, errors="ignore")
df['Ticket_Limit'] = df['Ticket_Limit'].astype(int, errors ='ignore')
df['Year'] = df['Year'].map(lambda x: x.lstrip('"').rstrip('1234567890"'))
df['Year'] = df['Year'].map(lambda x: x.lstrip('').rstrip('-'))
df['Year'] = df['Year'].map(lambda x: x.lstrip('"').rstrip('1234567890'))
df['Year'] = df['Year'].map(lambda x: x.lstrip('').rstrip('-'))
df['Month'] = df['Month'].map(lambda x: x.lstrip('"1234567890').rstrip('1234567890"'))
df['Month'] = df['Month'].map(lambda x: x.lstrip('-').rstrip(''))
df['Month'] = df['Month'].map(lambda x: x.lstrip('').rstrip(''))
df['Month'] = df['Month'].replace('-','',regex=True)
df['Day'] = df['Day'].map(lambda x: x.lstrip('"1234567890').rstrip('"'))
df['Day'] = df['Day'].map(lambda x: x.lstrip('-').rstrip(''))
df['Day'] = df['Day'].map(lambda x: x.lstrip('1234567890').rstrip(''))
df['Day'] = df['Day'].map(lambda x: x.lstrip('-').rstrip(''))

pd.set_option('display.max_columns', 999)

# %%
# Saving Dataframe to CSV for Next Part
df.to_csv('Event_Information_Dataframe5.csv', index=True, sep="\t")
