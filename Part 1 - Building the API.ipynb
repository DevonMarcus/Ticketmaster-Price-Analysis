# %%
# Importing Libraries

import numpy as np 
import pandas as pd
import requests
import urllib
import json                 
from pprint import pprint  
import csv

# %%
# Request to Get Access To API
Ticketmaster_API = requests.get('https://app.ticketmaster.com/discovery/v2/events.json?apikey=zDAxzTVTrzQ9NxJ48rOfSMrRmmHXZulL')
Ticketmaster_API
# Out:
# <Response [200]>

# %%
# Getting Data From API
Ticketmaster_Data = Ticketmaster_API.json()
Ticketmaster_Data
# Out:
# {'_embedded': {'events': [{'name': 'Los Angeles Chargers vs. Las Vegas Raiders',
#     'type': 'event',
#     'id': 'vvG1IZ9a9KiSJq',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/los-angeles-chargers-vs-las-vegas-inglewood-california-09-11-2022/event/0A005C95D3B3399D',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/bd0/e2cf0fbc-7e18-45ee-b651-60f99f94dbd0_1325431_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/bd0/e2cf0fbc-7e18-45ee-b651-60f99f94dbd0_1325431_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/bd0/e2cf0fbc-7e18-45ee-b651-60f99f94dbd0_1325431_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': False},
# ...

# %%
# Exploring Aspects of the API 
print(Ticketmaster_Data.keys())

print(Ticketmaster_Data['_embedded']['events'][0].keys())

print(Ticketmaster_Data['page'])
# Out:
# dict_keys(['_embedded', '_links', 'page'])
# dict_keys(['name', 'type', 'id', 'test', 'url', 'locale', 'images', 'sales', 'dates', 'classifications', 'promoter', 'promoters', 'priceRanges', 'products', 'seatmap', 'accessibility', 'ticketLimit', 'ageRestrictions', 'code', '_links', '_embedded'])
# {'size': 20, 'totalElements': 166246, 'totalPages': 8313, 'number': 0}

# %%
# Testing the API
Ticketmaster_Data = json.dumps(Ticketmaster_Data['_embedded']['events'][6], indent = 3)
print(Ticketmaster_Data)
# Out:
# {
#    "name": "Buffalo Bills vs. Pittsburgh Steelers",
#    "type": "event",
#    "id": "k7vGF9anx_U4y",
#    "test": false,
#    "url": "https://www.ticketmaster.com/buffalo-bills-vs-pittsburgh-steelers-orchard-park-new-york-10-09-2022/event/00005C9AA2676579",
#    "locale": "en-us",
#    "images": [
#       {
#          "ratio": "3_2",
#          "url": "https://s1.ticketm.net/dam/a/b37/f62cde9b-e0b9-4791-8d0b-929f42b7bb37_1325001_RETINA_PORTRAIT_3_2.jpg",
#          "width": 640,
#          "height": 427,
#          "fallback": false
#       },
#       {
#          "ratio": "16_9",
#          "url": "https://s1.ticketm.net/dam/a/b37/f62cde9b-e0b9-4791-8d0b-929f42b7bb37_1325001_TABLET_LANDSCAPE_16_9.jpg",
#          "width": 1024,
#          "height": 576,
#          "fallback": false
#       },
#       {
#          "ratio": "16_9",
#          "url": "https://s1.ticketm.net/dam/a/b37/f62cde9b-e0b9-4791-8d0b-929f42b7bb37_1325001_TABLET_LANDSCAPE_LARGE_16_9.jpg",
# ...

# %%
# Creating List of DMA's
DMA_List = [200
,
212
,
213
,
214
,
215
,
216
,
217
,
218
,
219
,
220
,
221
,
222
,
223
,
224
,
225
,
226
,
227
,
228
,
229
,
230
,
231
,
232
,
233
,
234
,
235
,
236
,
237
,
238
,
239
,
240
,
241
,
242
,
243
,
244
,
245
,
246
,
247
,
248
,
249
,
250
,
251
,
252
,
253
,
254
,
255
,
256
,
257
,
258
,
259
,
260
,
261
,
262
,
263
,
264
,
265
,
266
,
267
,
268
,
269
,
270
,
271
,
272
,
273
,
274
,
275
,
276
,
277
,
278
,
279
,
280
,
281
,
282
,
283
,
284
,
285
,
286
,
287
,
288
,
289
,
290
,
291
,
292
,
293
,
294
,
295
,
296
,
297
,
298
,
299
,
300
,
301
,
302
,
303
,
304
,
305
,
306
,
307
,
308
,
309
,
310
,
311
,
312
,
313
,
314
,
315
,
316
,
317
,
318
,
319
,
320
,
321
,
322
,
323
,
324
,
325
,
326
,
327
,
328
,
329
,
330
,
331
,
332
,
333
,
334
,
335
,
336
,
337
,
338
,
339
,
340
,
341
,
342
,
343
,
344
,
345
,
346
,
347
,
348
,
349
,
350
,
351
,
352
,
353
,
354
,
355
,
356
,
357
,
358
,
359
,
360
,
361
,
362
,
363
,
364
,
365
,
366
,
367
,
368
,
369
,
370
,
371
,
372
,
373
,
374
,
375
,
376
,
377
,
378
,
379
,
380
,
381
,
382
,
383
,
384
,
385
,
386
,
387
,
388
,
389
,
390
,
391
,
392
,
393
,
394
,
395
,
396
,
397
,
398
,
399
,
400
,
401
,
402
,
403
,
404
,
405
,
406
,
407
,
408
,
409
,
410
,
411
,
412
,
413
,
414
,
415
,
416
,
417
,
418
,
419
,
420
,
421
,
422
,
500
,
501
,
502
,
503
,
504
,
505
,
506
,
507
,
508
,
509
,
510
,
511
,
512
,
513
,
514
,
515
,
516
,
517
,
518
,
519
,
520
,
521
,
522
,
523
,
524
,
527
,
528
,
529
,
530
,
531
,
601
,
602
,
603
,
604
,
605
,
606
,
607
,
608
,
609
,
610
,
611
,
612
,
613
,
701
,
702
,
703
,
704
,
705
,
750
,
751
,
752
,
801
,
802
,
803
,
804
,
901
,
902
,
903]

# %%
print(DMA_List)
# Out:
# [200, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 41
# ...

# %%
# Creating The Different Columns of Data Taken from the API


# ID = json.dumps(EVENTS[2]['id'])
# Name = json.dumps(EVENTS[2]['name'])
# Type = json.dumps(EVENTS[2]['type'])
# Date = json.dumps(EVENTS[2]['dates']['start']['localDate'])
# Multiple_Days = json.dumps(EVENTS[2]['dates']['spanMultipleDays'])

# Home_Name = json.dumps(EVENTS[2]['_embedded']['attractions'][0]['name'])
# Segment_Home = json.dumps(EVENTS[2]['classifications'][0]['segment']['name'])
# Genre_Home = json.dumps(EVENTS[2]['classifications'][0]['genre']['name'])
# SubGenre_Home = json.dumps(EVENTS[2]['classifications'][0]['subGenre']['name'])
# Type_Home = json.dumps(EVENTS[6]['classifications'][0]['type']['name'])
# Sub_Type_Home = json.dumps(EVENTS[6]['classifications'][0]['subType']['name'])

# Away_Name = json.dumps(EVENTS[2]['_embedded']['attractions'][1]['name'])
# Segment_Away = json.dumps(EVENTS[6]['_embedded']['attractions'][1]['classifications'][0]['segment']['name'])
# Genre_Away = json.dumps(EVENTS[6]['_embedded']['attractions'][1]['classifications'][0]['genre']['name'])
# SubGenre_Away = json.dumps(EVENTS[6]['_embedded']['attractions'][1]['classifications'][0]['subGenre']['name'])
# Type_Away = json.dumps(EVENTS[6]['_embedded']['attractions'][1]['classifications'][0]['type']['name'])
# Sub_Type_Away = json.dumps(EVENTS[6]['_embedded']['attractions'][1]['classifications'][0]['subType']['name'])

# Away_2_Name = json.dumps(EVENTS[6]['_embedded']['attractions'][2]['name'])
# Segment_Away_2 = json.dumps(EVENTS[6]['_embedded']['attractions'][2]['classifications'][0]['segment']['name'])
# Genre_Away_2 = json.dumps(EVENTS[6]['_embedded']['attractions'][2]['classifications'][0]['genre']['name'])
# SubGenre_Away_2 = json.dumps(EVENTS[6]['_embedded']['attractions'][2]['classifications'][0]['subGenre']['name'])
# Type_Away_2 = json.dumps(EVENTS[6]['_embedded']['attractions'][2]['classifications'][0]['type']['name'])
# Sub_Type_Away_2 = json.dumps(EVENTS[6]['_embedded']['attractions'][2]['classifications'][0]['subType']['name'])

## Promoter = json.dumps(EVENTS[2]['promoter']['name'])
## Price_Ranges_Type = json.dumps(EVENTS[2]['priceRanges'][0]['type'])
## Price_Ranges_Currency = json.dumps(EVENTS[2]['priceRanges'][0]['currency'])
## Price_Ranges_Max = json.dumps(EVENTS[2]['priceRanges'][0]['max'])
## Price_Ranges_Min = json.dumps(EVENTS[2]['priceRanges'][0]['min'])
## Ticket_Limit = json.dumps(EVENTS[package]['accessibility']['ticketLimit'])
## Age_Restrictions = json.dumps(EVENTS[2]['ageRestrictions']['legalAgeEnforced'])

# Venue = json.dumps(EVENTS[2]['_embedded']['venues'][0]['name'])
## Venue_Alias = json.dumps(EVENTS[2]['_embedded']['venues'][0]['aliases'])
# Venue_Type = json.dumps(EVENTS[2]['_embedded']['venues'][0]['type'])
# Venue_City = json.dumps(EVENTS[2]['_embedded']['venues'][0]['city']['name'])
# Venue_State = json.dumps(EVENTS[2]['_embedded']['venues'][0]['state']['stateCode'])
# Venue_Country = json.dumps(EVENTS[2]['_embedded']['venues'][0]['country']['name'])
## Venue_Timezone = json.dumps(EVENTS[2]['_embedded']['venues'][0]['timezone'])

## Upcoming_Events_Venue = json.dumps(EVENTS[2]['_embedded']['venues'][0]['upcomingEvents']['_total'])
# Upcoming_Events_Home = json.dumps(EVENTS[6]['_embedded']['attractions'][0]['upcomingEvents']['_total'])
# Upcoming_Events_Away = json.dumps(EVENTS[6]['_embedded']['attractions'][1]['upcomingEvents']['_total'])
# Upcoming_Events_Away_2 = json.dumps(EVENTS[6]['_embedded']['attractions'][2]['upcomingEvents']['_total'])

# Home_Name = json.dumps(EVENTS[2]['_embedded']['attractions'][0]['name'])
# Home_Twitter = json.dumps(EVENTS[2]['_embedded']['attractions'][0]['externalLinks']['twitter'][0]['url'])
# Home_Facebook = json.dumps(EVENTS[2]['_embedded']['attractions'][0]['externalLinks']['facebook'][0]['url'])
# Home_Instagram = json.dumps(EVENTS[2]['_embedded']['attractions'][0]['externalLinks']['instagram'][0]['url'])
# Home_Youtube = json.dumps(EVENTS[2]['_embedded']['attractions'][0]['externalLinks']['youtube'][0]['url'])
# Home_Homepage = json.dumps(EVENTS[2]['_embedded']['attractions'][0]['externalLinks']['homepage'][0]['url'])
# Home_Wiki = json.dumps(EVENTS[2]['_embedded']['attractions'][0]['externalLinks']['wiki'][0]['url'])
# Social_Media_Total_Home = len(json.dumps(EVENTS[2]['_embedded']['attractions'][0]['externalLinks']))

# Away_Name = json.dumps(EVENTS[2]['_embedded']['attractions'][1]['name'])
# Away_Twitter = json.dumps(EVENTS[2]['_embedded']['attractions'][1]['externalLinks']['twitter'][0]['url'])
# Away_Facebook = json.dumps(EVENTS[2]['_embedded']['attractions'][1]['externalLinks']['facebook'][0]['url'])
# Away_Instagram = json.dumps(EVENTS[2]['_embedded']['attractions'][1]['externalLinks']['instagram'][0]['url'])
# Away_Homepage = json.dumps(EVENTS[2]['_embedded']['attractions'][1]['externalLinks']['homepage'][0]['url'])
# Away_Wiki = json.dumps(EVENTS[2]['_embedded']['attractions'][1]['externalLinks']['wiki'][0]['url'])
# Social_Media_Total_Away = len(json.dumps(EVENTS[2]['_embedded']['attractions'][1]['externalLinks']))








# Info = ['ID','Name','Type','Date','Multiple_Days','Home_Name','Segment_Home','Genre_Home','Sub_Genre_Home','Type_Home','Sub_Type_Home','Away_Name','Segment_Away','Genre_Away','Sub_Genre_Away','Type_Away','Sub_Type_Away','Away_2_Name','Segment_Away_2','Genre_Away_2','Sub_Genre_Away_2','Type_Away_2','Sub_Type_Away_2','Promoter','Price_Ranges_Type','Price_Ranges_Currency','Price_Ranges_Max','Price_Ranges_Min','Ticket_Limit', 'Age_Restrictions','Venue','Venue_Alias','Venue_Type','Venue_City','Venue_State','Venue_Country','Venue_Timezone','Upcoming_Events_Venue','Upcoming_Events_Home','Upcoming_Events_Away','Upcoming_Events_Away_2','Home_Name','Home_Twitter','Home_Facebook','Home_Instagram','Home_Youtube','Home_Homepage','Home_Wiki','Social_Media_Total_Home','Away_Name','Away_Twitter','Away_Facebook','Away_Instagram','Away_Homepage','Away_Wiki','Social_Media_Total_Away']

# Info = [
# ID,
# Name,
# Type,  
# Date, 
# Multiple_Days,
# Home_Name,
# Segment_Home,
# Genre_Home,
# Sub_Genre_Home,
# Type_Home,
# Sub_Type_Home,
# Away_Name,
# Segment_Away,
# Genre_Away,
# Sub_Genre_Away,
# Type_Away,
# Sub_Type_Away,
# Away_2_Name,
# Segment_Away_2,
# Genre_Away_2,
# Sub_Genre_Away_2,
# Type_Away_2,
# Sub_Type_Away_2,
# Promoter,
# Price_Ranges_Type,
# Price_Ranges_Currency,
# Price_Ranges_Max,
# Price_Ranges_Min,
# Ticket_Limit, 
# Age_Restrictions,
# Venue,
# Venue_Alias,
# Venue_Type,
# Venue_City,
# Venue_State,
# Venue_Country,
# Venue_Timezone,
# Upcoming_Events_Venue,
# Upcoming_Events_Home,
# Upcoming_Events_Away,
# Upcoming_Events_Away_2,
# Home_Name,
# Home_Twitter,
# Home_Facebook,
# Home_Instagram,
# Home_Youtube,
# Home_Homepage,
# Home_Wiki,
# Social_Media_Total_Home,
# Away_Name,
# Away_Twitter,
# Away_Facebook,
# Away_Instagram,
# Away_Homepage,
# Away_Wiki,
# Social_Media_Total_Away,
# ]

# results = []
# for package in range(0,20):
#     name = json.dumps(EVENTS[package]['name'])
#     Type = json.dumps(EVENTS[package]['type'])
#     ID = json.dumps(EVENTS[package]['id'])
#     Date = json.dumps(EVENTS[package]['dates']['start']['localDate'])
#     Multiple_Days = json.dumps(EVENTS[package]['dates']['spanMultipleDays'])
#     Segment = json.dumps(EVENTS[package]['classifications'][0]['segment']['name'])
#     genre = json.dumps(EVENTS[package]['classifications'][0]['genre']['name'])
#     subGenre = json.dumps(EVENTS[package]['classifications'][0]['subGenre']['name'])
#         Ticket_Limit = json.dumps(EVENTS[package]['accessibility']['ticketLimit'])
#         Venue_Alias = json.dumps(EVENTS[2]['_embedded']['venues'][0]['aliases'])


# #     Promoter = json.dumps(EVENTS[package]['promoter']['name'])
# #     PriceRangesType = json.dumps(EVENTS[package]['priceRanges'][0]['type'])
# #     PriceRangesCurrency = json.dumps(EVENTS[package]['priceRanges'][0]['currency'])
# #     PriceRangesMax = json.dumps(EVENTS[package]['priceRanges'][0]['max'])
# #     PriceRangesMin = json.dumps(EVENTS[package]['priceRanges'][0]['min'])
# #     AgeRestrictions = json.dumps(EVENTS[package]['ageRestrictions']['legalAgeEnforced'])
#     Venue = json.dumps(EVENTS[package]['_embedded']['venues'][0]['name'])
#     VenueType = json.dumps(EVENTS[package]['_embedded']['venues'][0]['type'])
#     VenueCity = json.dumps(EVENTS[package]['_embedded']['venues'][0]['city']['name'])
#     VenueState = json.dumps(EVENTS[package]['_embedded']['venues'][0]['state']['stateCode'])
#     VenueCountry = json.dumps(EVENTS[package]['_embedded']['venues'][0]['country']['name'])


#     Info = [name,Type, ID, Date, Multiple_Days,Segment,genre,subGenre,Ticket_Limit, Venue,Venue_Alias,
#       VenueType,VenueCity,VenueState,VenueCountry,Venue_Timezone]
#     results.append(Info)
